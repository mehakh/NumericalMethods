# %% [markdown]
# <a href="https://colab.research.google.com/github/mehakh/NumericalMethods/blob/main/Lab1Numerical.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as mehdi
from matplotlib import pyplot as plt
import os

# Mehdi Akhundzada
# Enter the coefficients of the given polynomial

cf = [-1.35, -0.93, 26.46, 16.20, -76.19]

a = mehdi.roots(cf)
# Print the results of function using   mehdi.roots
# print(mehdi.roots(cf))
# print(mehdi.poly1d(cf))
print("Given Polynomial:\n\n", mehdi.poly1d(cf), "\nObtained results:\n", a)

x = mehdi.linspace(-5, 5, num=100, endpoint= False)

fx = []
for i in range(len(x)):
    fx.append(-1.35 * x[i] ** 4 - 0.93 * x[i] ** 3 + 26.46 * x[i] ** 2 + 16.20 * x[i] - 76.19)

plt.title("Function f(x) Polynomial M.Akhundzada")
plt.grid()

plt.xlabel("X axis ")
plt.ylabel("Y axis ")
#plt.ylim(-25,25)
#plt.xlim(-25,25)
plt.plot(x, fx, "--", color="black")
plt.show()
# Data for plotting
#x0=mehdi.linspace(-10, 10 , num=100)
#xx = []
#for i in range(len(x0)):
#  fxx.append()


def f(x):
  return (mehdi.log(x)/(mehdi.sin(2*x)+1.5))-(x/7)


x = mehdi.arange(1,10,0.1)
y = f(x) 
plt.plot(x,y)
plt.show()

 #given function
def fx(x):
  return -1.35*x**4-0.93*x**3+26.46*x**2 +16.20*x-76.19


 #bisection method
def bisection(func, xFrom, xTo):
    xmid = (xFrom + xTo) / 2
    iter = 0
    while (mehdi.abs(func(xmid)) > 1e-10):
        iter += 1
        if (mehdi.sign(func(xmid)) == mehdi.sign(func(xFrom))):
            xFrom = xmid
        else:
            xTo = xmid
        xmid = (xFrom + xTo) / 2
        print('x = {0:.20f} f(x) = {1:.20f}'.format(xmid, func(xmid)))
    print('Total iteration: = {0}'.format(iter))
    return xmid



 #finding root in specified range [-5; -4]
x1 = bisection(fx, 4.5, -4.5)
print('x = {0:.20f} f(x) = {1:.20f}'.format(x1, fx(x1)))
x = mehdi.linspace(-4.5, 4, 100)
y = fx(x)
plt.plot(x,y)
plt.plot(x1, fx(x1), markersize=10, marker='o')


def t(x):
  return
# Out:
# Given Polynomial:
#
#         4        3         2
# -1.35 x - 0.93 x + 26.46 x + 16.2 x - 76.19
# Obtained results:
#  [ 4.04099735 -3.96368695 -2.29889758  1.53269828]
# x = -2.25000000000000000000 f(x) = -2.69199218749997726263
# x = -3.37500000000000000000 f(x) = 31.12570556640623919975
# x = -2.81250000000000000000 f(x) = 23.76996475219726789874
# x = -2.53125000000000000000 f(x) = 12.00103112220764955964
# x = -2.39062500000000000000 f(x) = 4.91533837854862554195
# x = -2.32031250000000000000 f(x) = 1.16448420617730619142
# x = -2.28515625000000000000 f(x) = -0.75205710762878652531
# x = -2.30273437500000000000 f(x) = 0.20932407349013715248
# x = -2.29394531250000000000 f(x) = -0.27061229478326254139
# x = -2.29833984375000000000 f(x) = -0.03045263653130803050
# x = -2.30053710937500000000 f(x) = 0.08948395248702922800
# x = -2.29943847656250000000 f(x) = 0.02952767076541817914
# x = -2.29888916015625000000 f(x) = -0.00045948539775508834
# x = -2.29916381835937500000 f(x) = 0.01453484276896688243
# x = -2.29902648925781250000 f(x) = 0.00703786611767043269
# x = -2.29895782470703125000 f(x) = 0.00328923720678631071
# x = -2.29892349243164062500 f(x) = 0.00141488761485675241
# x = -2.29890632629394531250 f(x) = 0.00047770403597269251
# x = -2.29889774322509765625 f(x) = 0.00000911005092518735
# x = -2.29889345169067382812 f(x) = -0.00022518749045730146
# x = -2.29889559745788574219 f(x) = -0.00010803867402842116
# x = -2.29889667034149169922 f(x) = -0.00004946430013319514
# x = -2.29889720678329467773 f(x) = -0.00002017712174051667
# x = -2.29889747500419616699 f(x) = -0.00000553353467580564
# x = -2.29889760911464691162 f(x) = 0.00000178825828811568
# x = -2.29889754205942153931 f(x) = -0.00000187263812279070
# x = -2.29889757558703422546 f(x) = -0.00000004218992444294
# x = -2.29889759235084056854 f(x) = 0.00000087303419604723
# x = -2.29889758396893739700 f(x) = 0.00000041542213580215
# x = -2.29889757977798581123 f(x) = 0.00000018661611989046
# x = -2.29889757768251001835 f(x) = 0.00000007221308351291
# x = -2.29889757663477212191 f(x) = 0.00000001501157953498
# x = -2.29889757611090317369 f(x) = -0.00000001358914403227
# x = -2.29889757637283764780 f(x) = 0.00000000071122485679
# x = -2.29889757624187041074 f(x) = -0.00000000643896669317
# x = -2.29889757630735402927 f(x) = -0.00000000286385670734
# x = -2.29889757634009583853 f(x) = -0.00000000107635855784
# x = -2.29889757635646674316 f(x) = -0.00000000018256685053
# x = -2.29889757636465219548 f(x) = 0.00000000026433610856
# x = -2.29889757636055946932 f(x) = 0.00000000004087041816
# Total iteration: = 40
# x = -2.29889757636055946932 f(x) = 0.00000000004087041816
